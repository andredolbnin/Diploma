# %%
import numpy as np
import sympy as sp
from numpy import linalg 
import matplotlib.pyplot as plt

# %% [markdown]
# $$\int_{a}^b f(x)dx \approx h \sum_{i=0}^{n-1} f(x_i) , h = \frac{b - a}{n} , x_i = \frac{h}{2} + ih$$

# %%
#counting integral
def I(a, b, xm):
    intN = 50
    intH = (b - a) / intN
    intX = np.zeros((N, 1))
    intF = np.zeros((N, 1))
    sum = 0
    for i in range(intN):
        intX[i] = (intH / 2) + i * intH + a
        intF[i] = np.log(1 / np.abs(xm - intX[i]))
        sum += intF[i]
    return sum * intH

# %% [markdown]
# $$\int_{0}^1 \ln \frac{1}{|x - s|} \phi (s)ds = 1$$
# $$\sum_{n=0}^{N - 1} a_{mn} {\phi}_n = f_m, a_{mn} = \int_{nh}^{(n+1)h} \ln \frac{1}{|x_m - s|} ds , f_m = 1, m \in [1, N - 1]$$

# %%
N = 100

h = 1 / N

XM = np.zeros((N, 1))
for i in range(N):
    XM[i] = 0 + (h / 2) + i * h

#SN = []
SN = np.zeros((N + 1, 1))
for j in range(N + 1):
    SN[j] = 0 + j * h 
    
#creating linear system
mat = np.zeros((N, N), dtype = np.complex)
for m in range(N):
    for n in range(N):
        mat[m, n] = I(SN[n], SN[n + 1], XM[m])

right = np.full((N, 1), 1, dtype = np.complex)

answer = linalg.solve(mat, right)

plt.rcParams['figure.figsize'] = [10, 8]

res_real = np.real(answer)
plt.plot(XM, res_real, 'bo', color = 'black')
plt.grid()
plt.show()

# %%
#calculation of exact sln in XM
S = np.zeros((N, 1))
def sln(x):
    return 1 / (2 * np.pi * np.log(2) * np.sqrt(x * (1 - x)))
for i in range(N):
    S[i] = sln(XM[i])
plt.plot(XM, S, 'bo', color = 'red')
plt.grid()
plt.show()

# %%
plt.plot(XM, res_real, 'bo', color = 'black')
plt.plot(XM, S, 'bo', color = 'red')
plt.grid()
plt.show()

# %%
error = np.zeros((N, 1))
for i in range(N):
    error[i] = np.abs(res_real[i] - S[i])
print("Abs. error = ", max(error))
print("Abs. error without boundaries = ", max(error[1 : N - 1]))
plt.plot(XM, error, 'bo', color = 'green')
plt.grid()
plt.show()
# Out:
# Abs. error =  [1.14516539]
# Abs. error without boundaries =  [0.04060622]

# %%
#finding residual in x_m = 0.5 + 0.01/2 = 0.505 - middle point

print(XM[50])

r1 = np.zeros((N, 1))
for n in range(N):
    numSln = res_real[n] * np.log(1 / np.abs(XM[50] - SN[n]))
    r1[n] = numSln - 1

print("max r = ", max(r1[1 : N - 1]))

plt.plot(SN[1 : N - 1], r1[1 : N - 1], 'bo', color = "brown", label = XM[50])

plt.legend(bbox_to_anchor=(0.95, 0.95),
           bbox_transform=plt.gcf().transFigure)

plt.xlim(-0.1, 1.1)
plt.ylim(-1.5, 2.0)

plt.ylabel("r")

plt.grid()
plt.show()
# Out:
# [0.505]
# max r =  [1.4365127]

# %%
#finding residual in x_m = 0.2 + 0.01/2 = 0.205 

print(XM[20])

r2 = np.zeros((N, 1))
for n in range(N):
    numSln = res_real[n] * np.log(1 / np.abs(XM[20] - SN[n]))
    r2[n] = numSln - 1

print("max r = ", max(r2[1 : N - 1]))

plt.plot(SN[2 : N - 1], r2[2 : N - 1], 'bo', color = "brown", label = XM[20])

plt.legend(bbox_to_anchor=(0.95, 0.95),
           bbox_transform=plt.gcf().transFigure)

plt.xlim(-0.1, 1.1)
plt.ylim(-1.5, 2.2)

plt.ylabel("r")

plt.grid()
plt.show()
# Out:
# [0.205]
# max r =  [2.06374759]

# %%
#finding residual in xm = 0.0 + 0.01/2 = 0.005 - boundary point

print(XM[0])

r3 = np.zeros((N, 1))
for n in range(N):
    numSln = res_real[n] * np.log(1 / np.abs(XM[0] - SN[n]))
    r3[n] = numSln - 1

print("max r = ", max(r3[1 : N - 1]))

plt.plot(SN[1 : N - 1], r3[1 : N - 1], 'bo', color = "brown", label = XM[0])

plt.legend(bbox_to_anchor=(0.95, 0.95),
           bbox_transform=plt.gcf().transFigure)

#plt.xlim(-0.1, 1.1)
#plt.ylim(-1.5, 2.0)

plt.ylabel("r")

plt.grid()
plt.show()
# Out:
# [0.005]
# max r =  [8.92974476]
